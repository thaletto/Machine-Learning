# %% [markdown]
# # 19CSE305: MACHINE LEARNING LAB **2**

# %% [markdown]
# PYTHON PANDAS EXCERCISES
#
# ROLL NUMBER: CB.EN.U4CSE20234

# %% [markdown]
# **Set 1**
#
# 1. How to create a series from a list, numpy array and dict?
#
# 2. How to convert the index of a series into a column of a dataframe?
#
# 3. How to combine many series to form a dataframe?
#
# 4. How to assign name to the series’ index?
#
# 5. How to get the items of series A not present in series B?
#
# 6. How to get the items not common to both series A and series B?
#
# 7. How to get the minimum, 25th percentile, median, 75th, and max of a numeric series?
#
# 8. How to get frequency counts of unique items of a series?
#
# 9. How to keep only top 2 most frequent values as it is and replace everything else as ‘Other’?
#
# 10. How to bin a numeric series to 10 groups of equal size?
#
# 11. How to convert a numpy array to a dataframe of given shape?
#
# 12. How to find the positions of numbers that are multiples of 3 from a series?
#
# 13. How to extract items at given positions from a series
#
# 14. How to stack two series vertically and horizontally ?
#
# 15. How to get the positions of items of series A in another series B?
#
# 16. How to compute the mean squared error on a truth and predicted series?
#
# 17. How to convert the first character of each element in a series to uppercase?
#
# 18. How to calculate the number of characters in each word in a series?
#
# 19. How to compute difference of differences between consequtive numbers of a series?
#
# 20. How to convert a series of date-strings to a timeseries?
#
# 21.  How to get the day of month, week number, day of year and day of week from a series of date strings?
#
# 22. How to convert year-month string to dates corresponding to the 4th day of the month?
#
# 23. How to filter words that contain atleast 2 vowels from a series?
#
# 24. How to filter valid emails from a series?
#
# 25. How to get the mean of a series grouped by another series?
#
# 26. How to compute the euclidean distance between two series?
#
# 27. How to find all the local maxima (or peaks) in a numeric series?
#
# 28. How to replace missing spaces in a string with the least frequent character?
#
# 29. How to create a TimeSeries starting ‘2000-01-01’ and 10 weekends (saturdays) after that having random numbers as values?
#
# 30. How to fill an intermittent time series so all missing dates show up with values of previous non-missing date?
#
# 31. How to compute the autocorrelations of a numeric series?
#
# 32. How to import only every nth row from a csv file to create a dataframe?
#
# 33. How to import only specified columns from a csv file?
#
# 34. How to get the nrows, ncolumns, datatype, summary stats of each column of a dataframe? Also get the array and list equivalent.
#
# 35. How to extract the row and column number of a particular cell with given criterion?
#
# 36. How to rename a specific columns in a dataframe?
#
# 37. How to select a specific column from a dataframe as a dataframe instead of a series?
#
# 38. How to change the order of columns of a dataframe?
#
# 39. How to set the number of rows and columns displayed in the output?
#
# 40. How to format or suppress scientific notations in a pandas dataframe?
#
# 41. How to format all the values in a dataframe as percentages?
#
# 42. How to filter every nth row in a dataframe?
#
# 43. How to create a primary key index by combining relevant columns?
#
# 44. How to get the row number of the nth largest value in a column?
#
# 45. How to find the position of the nth largest value greater than a given value?
#
# 46. How to get the last n rows of a dataframe with row sum > 100?
#
# 47. How to find and cap outliers from a series or dataframe column?
#
# 48. How to reshape a dataframe to the largest possible square after removing the negative values?
#
# 49. How to swap two rows of a dataframe?
#
# 50. How to reverse the rows of a dataframe?
#
# 51. Which column contains the highest number of row-wise maximum values?
#
# 52. How to create a new column that contains the row number of nearest column by euclidean distance?
#
# 53. How to create a column containing the minimum by maximum of each row?
#
# 54. How to replace both the diagonals of dataframe with 0?
#
# 55. How to get the particular group of a groupby dataframe by key?
#
# 56. How to get the n’th largest value of a column when grouped by another column?
#
# 57. How to compute grouped mean on pandas dataframe and keep the grouped column as another column (not index)?
#
# 58. How to join two dataframes by 2 columns so they have only the common rows?
#
# 59. How to get the positions where values of two columns match?
#
# 60. How to get the frequency of unique values in the entire dataframe?
#
# 61. How to split a text column into two separate columns?
#
# 62. How to change column values when importing csv to a dataframe?
#
# **Reference**
# https://www.machinelearningplus.com/python/101-pandas-exercises-python/
#
# https://www.geeksforgeeks.org/pandas-practice-excercises-questions-and-solutions/

# %% [markdown]
# **MatPlotlib and Seaborn**
#
# ***Set 1:***
# Upload the dataset Company_sales_data.csv and complete the following task
#
# 1: Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties: –
#
# X label name = Month Number
# Y label name = Total profit
#
# 2: Get total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties:–
#
# Line Style dotted and Line-color should be red
# Show legend at the lower right location.
# X label name = Month Number
# Y label name = Sold units number
# Add a circle marker.
# Line marker color as read
# Line width should be 3
#
# 3: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# 4: Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot. gridline style should “–“.
#
#  5: Read face cream and facewash product sales data and show it using the bar chart
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# 10: Read all product sales data and show it using the stack plot
#
# Reference:
# https://pynative.com/python-matplotlib-exercise/
# https://www.analyticsvidhya.com/blog/2019/09/comprehensive-data-visualization-guide-seaborn-python/
#
# ***Set 2:***
# Refer and complete it
#
# https://harvard-iacs.github.io/2019-CS109A/labs/lab-5/student/
