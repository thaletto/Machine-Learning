# %%
import numpy as np

# 1.
import pandas as pd
print(pd.__version__)
print(pd.show_versions(as_json=True))

# 2. 
mylist = list('abcedfghijklmnopqrstuvwxyz')
myarr = np.arange(26)
mydict = dict(zip(mylist, myarr))
series_list = pd.Series(mylist)
print(series_list.head())
series_array = pd.Series(myarr)
print(series_array.head())
series_dict= pd.Series(mydict)
print(series_dict.head())

# 3. 
ser = pd.Series(mydict)
df = ser.to_frame().reset_index()
print(df.head())

# 4. 
ser1 = pd.Series(list('abcedfghijklmnopqrstuvwxyz'))
ser2 = pd.Series(np.arange(26))
df_v1 = pd.concat([ser1, ser2])
print(df_v1.head())
df_v2 = pd.DataFrame({'col1': ser1, 'col2': ser2})
print(df_v2.head())


# 5.
ser = pd.Series(list('abcedfghijklmnopqrstuvwxyz'))
ser.name = 'alphabets'
print(ser.head())

# 6. 
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])
ser1[~ser1.isin(ser2)]

# 7. 
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])
ser_u = pd.Series(np.union1d(ser1,ser2))
ser_i = pd.Series(np.intersect1d(ser1,ser2))
ser_u[~ser_u.isin(ser_i)]
pd.Series(np.append(np.setdiff1d(ser1,ser2), np.setdiff1d(ser2,ser1)))

# 8
state = np.random.RandomState(100)
ser = pd.Series(state.normal(10, 5, 25))
np.percentile(ser, q=[0, 25, 50, 75, 100])

# 9. 
ser = pd.Series(np.take(list('abcdefgh'), np.random.randint(8, size=30)))
ser.value_counts()

# 10.
np.random.RandomState(100)
ser = pd.Series(np.random.randint(1, 5, [12]))
two_most_freq = ser.value_counts().index[:2]
ser[~ser.isin(two_most_freq)] = "Other"

# 11. 
ser = pd.Series(np.random.random(20))
print(ser.head())
ser_binned = pd.qcut(ser,
        q=[0, .10, .20, .3, .4, .5, .6, .7, .8, .9, 1],
        labels=['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th'])
print(ser_binned.head())


# 12.  
ser = pd.Series(np.random.randint(1, 10, 35))
df = pd.DataFrame(ser.values.reshape(7,5))
print(df)

# 13. 
ser = pd.Series(np.random.randint(1, 10, 7))
np.argwhere(ser % 3 == 0)

# 14. 
ser = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))
pos = [0, 4, 8, 14, 20]
ser.take(pos)

# 15.
ser1 = pd.Series(range(5))
ser2 = pd.Series(list('abcde'))
df_vert = ser1.append(ser2)
print(df_vert)
df_vert2 = pd.concat([ser1,ser2], axis=0)
print(df_vert)
df_horiz = pd.concat([ser1,ser2], axis=1)

# 16.
ser1 = pd.Series([10, 9, 6, 5, 3, 1, 12, 8, 13])
ser2 = pd.Series([1, 3, 10, 13])
match_idx1 = [np.where(i == ser1)[0].tolist()[0] for i in ser2]
match_idx2 = [pd.Index(ser1).get_loc(i) for i in ser2]


# 17. 
truth = pd.Series(range(10))
pred = pd.Series(range(10)) + np.random.random(10)
np.mean((truth-pred)**2)
pd.Series((truth-pred)**2).mean()

#18. 
ser = pd.Series(['how', 'to', 'kick', 'ass?'])
ser.map(lambda x: x.title())
ser.map(lambda x: x[0].upper() + x[1:])
pd.Series(i.title() for i in ser)


#19. 
ser.map(lambda x: len(x))
pd.Series(len(i) for i in ser)


# 20.
ser = pd.Series([1, 3, 6, 10, 15, 21, 27, 35])
print(ser.diff().tolist())
print(ser.diff().diff().tolist())
# Out:
# 1.5.0
# {
#   "system": {
#     "commit": "87cfe4e38bafe7300a6003a1d18bd80f3f77c763",
#     "python": "3.10.1.final.0",
#     "python-bits": 64,
#     "OS": "Windows",
#     "OS-release": "10",
#     "Version": "10.0.22000",
#     "machine": "AMD64",
#     "processor": "Intel64 Family 6 Model 126 Stepping 5, GenuineIntel",
#     "byteorder": "little",
#     "LC_ALL": null,
#     "LANG": null,
#     "LOCALE": {
#       "language-code": "English_India",
#       "encoding": "1252"
#     }
#   },
#   "dependencies": {
#     "pandas": "1.5.0",
#     "numpy": "1.23.3",
#     "pytz": "2022.2.1",
#     "dateutil": "2.8.2",
#     "setuptools": "58.1.0",
#     "pip": "21.2.4",
#     "Cython": null,
#     "pytest": null,
#     "hypothesis": null,
#     "sphinx": null,
#     "blosc": null,
#     "feather": null,
#     "xlsxwriter": null,
#     "lxml.etree": null,
#     "html5lib": null,
#     "pymysql": null,
#     "psycopg2": null,
#     "jinja2": null,
#     "IPython": "8.5.0",
#     "pandas_datareader": null,
#     "bs4": null,
#     "bottleneck": null,
#     "brotli": null,
#     "fastparquet": null,
#     "fsspec": null,
#     "gcsfs": null,
#     "matplotlib": "3.6.2",
#     "numba": null,
#     "numexpr": null,
#     "odfpy": null,
#     "openpyxl": null,
#     "pandas_gbq": null,
#     "pyarrow": null,
#     "pyreadstat": null,
#     "pyxlsb": null,
#     "s3fs": null,
#     "scipy": "1.9.3",
#     "snappy": null,
#     "sqlalchemy": null,
#     "tables": null,
#     "tabulate": null,
#     "xarray": null,
#     "xlrd": null,
#     "xlwt": null,
#     "zstandard": null,
#     "tzdata": null
#   }
# }None
# 0    a
# 1    b
# 2    c
# 3    e
# 4    d
# dtype: object
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int32
# a    0
# b    1
# c    2
# e    3
# d    4
# dtype: int32
#   index  0
# 0     a  0
# 1     b  1
# 2     c  2
# 3     e  3
# 4     d  4
# 0    a
# 1    b
# 2    c
# 3    e
# 4    d
# dtype: object
#   col1  col2
# 0    a     0
# 1    b     1
# 2    c     2
# 3    e     3
# 4    d     4
# 0    a
# 1    b
# 2    c
# 3    e
# 4    d
# Name: alphabets, dtype: object
# 0    0.188907
# 1    0.183706
# 2    0.738973
# 3    0.761336
# 4    0.373062
# dtype: float64
# 0     4th
# 1     3rd
# 2     8th
# 3    10th
# 4     5th
# dtype: category
# Categories (10, object): ['1st' < '2nd' < '3rd' < '4th' ... '7th' < '8th' < '9th' < '10th']
#    0  1  2  3  4
# 0  6  3  9  3  1
# 1  4  6  2  6  4
# 2  8  8  6  4  2
# 3  9  8  2  4  8
# 4  3  4  7  5  1
# 5  2  1  5  9  9
# 6  2  8  1  6  8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 82
#      80 # 13.
#      81 ser = pd.Series(np.random.randint(1, 10, 7))
# ---> 82 np.argwhere(ser % 3 == 0)
#      84 # 14.
#      85 ser = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))
#
# File <__array_function__ internals>:180, in argwhere(*args, **kwargs)
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\numeric.py:624, in argwhere(a)
#     622     # then remove the added dimension
#     623     return argwhere(a)[:,:0]
# --> 624 return transpose(nonzero(a))
#
# File <__array_function__ internals>:180, in nonzero(*args, **kwargs)
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1958, in nonzero(a)
#    1866 @array_function_dispatch(_nonzero_dispatcher)
#    1867 def nonzero(a):
#    1868     """
#    1869     Return the indices of the elements that are non-zero.
#    1870
#    (...)
#    1956
#    1957     """
# -> 1958     return _wrapfunc(a, 'nonzero')
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:47, in _wrapit(obj, method, *args, **kwds)
#      45     if not isinstance(result, mu.ndarray):
#      46         result = asarray(result)
# ---> 47     result = wrap(result)
#      48 return result
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2106, in NDFrame.__array_wrap__(self, result, context)
#    2104     return res
#    2105 d = self._construct_axes_dict(self._AXIS_ORDERS, copy=False)
# -> 2106 return self._constructor(res, **d).__finalize__(self, method="__array_wrap__")
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:462, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     460     index = default_index(len(data))
#     461 elif is_list_like(data):
# --> 462     com.require_length_match(data, index)
#     464 # create/copy the manager
#     465 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File c:\Users\Laxman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (1) does not match length of index (7)
